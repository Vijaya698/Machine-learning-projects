# %%
import pandas as pd
df=pd.read_excel("weather_data_XL.xlsx")

# %%
df
# Out:
#         Date        City  Temperature_C  Humidity_% Condition
# 0 2025-01-01    Hyderbad             28          60     Sunny
# 1 2025-01-02    Hyderbad             29          62     Sunny
# 2 2025-01-03    Hyderbad             30          58    Cloudy
# 3 2025-01-04    Hyderbad             31          55    Cloudy
# 4 2025-01-05    Banglore             32          57     Rainy
# 5 2025-01-06    Banglore             33          59     Rainy
# 6 2025-01-07    Banglore             34          61     Sunny
# 7 2025-01-08    Banglore             32          63    Cloudy
# 8 2025-01-09  Vijayawada             31          64     Rainy
# 9 2025-01-10  Vijayawada             29          62     Sunny

# %% [markdown]
# # Statistics analysis

# %%
df.Temperature_C.min()
# Out:
# 28

# %%
df.Temperature_C.max()
# Out:
# 34

# %%
df.Temperature_C.mean()
# Out:
# np.float64(30.9)

# %%
df.Temperature_C.std()
# Out:
# 1.911950719959998

# %%
df.Temperature_C.var()
# Out:
# 3.6555555555555554

# %%
df.Temperature_C.count()
# Out:
# np.int64(10)

# %%
df.Temperature_C.sum()
# Out:
# np.int64(309)

# %%
df.describe()
# Out:
#                       Date  Temperature_C  Humidity_%
# count                   10      10.000000    10.00000
# mean   2025-01-05 12:00:00      30.900000    60.10000
# min    2025-01-01 00:00:00      28.000000    55.00000
# 25%    2025-01-03 06:00:00      29.250000    58.25000
# 50%    2025-01-05 12:00:00      31.000000    60.50000
# 75%    2025-01-07 18:00:00      32.000000    62.00000
# max    2025-01-10 00:00:00      34.000000    64.00000
# std                    NaN       1.911951     2.84605

# %%
df.Temperature_C.describe()
# Out:
# count    10.000000
# mean     30.900000
# std       1.911951
# min      28.000000
# 25%      29.250000
# 50%      31.000000
# 75%      32.000000
# max      34.000000
# Name: Temperature_C, dtype: float64

# %% [markdown]
# # New Data

# %%
import pandas as pd
df=pd.read_csv("mobile_usage_data.csv")

# %%
df
# Out:
#          Date        Day  Screen_Time_Hours  Data_Used_GB
# 0  01-02-2025     Monday                4.5           1.2
# 1  02-02-2025    Tuesday                5.2           1.5
# 2  03-02-2025  Wednesday                6.0           2.0
# 3  04-02-2025   Thursday                4.8           1.8
# 4  05-02-2025     Friday                5.5           1.4
# 5  06-02-2025   Saturday                7.0           2.5
# 6  07-02-2025     Sunday                6.5           3.5

# %% [markdown]
# #Statistical analysis

# %%
df.Screen_Time_Hours.min()
# Out:
# 4.5

# %%
df.Screen_Time_Hours.max()
# Out:
# 7.0

# %%
df.Screen_Time_Hours.mean()
# Out:
# np.float64(5.642857142857143)

# %%
df.Screen_Time_Hours.std()
# Out:
# 0.9071147352221454

# %%
df.Screen_Time_Hours.var()
# Out:
# 0.8228571428571428

# %%
df.Screen_Time_Hours.count()
# Out:
# np.int64(7)

# %%
df.Screen_Time_Hours.sum()
# Out:
# np.float64(39.5)

# %%
df.describe()
# Out:
#        Screen_Time_Hours  Data_Used_GB
# count           7.000000      7.000000
# mean            5.642857      1.985714
# std             0.907115      0.794625
# min             4.500000      1.200000
# 25%             5.000000      1.450000
# 50%             5.500000      1.800000
# 75%             6.250000      2.250000
# max             7.000000      3.500000

# %%
df.Screen_Time_Hours.describe()
# Out:
# count    7.000000
# mean     5.642857
# std      0.907115
# min      4.500000
# 25%      5.000000
# 50%      5.500000
# 75%      6.250000
# max      7.000000
# Name: Screen_Time_Hours, dtype: float64
